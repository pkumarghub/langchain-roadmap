# %% [markdown]
# Exercise: Streaming ⭐⭐⭐
# Goal
#
# Instead of
#
# Waiting...
#
# show
#
# H
# He
# Hel
# Hell
# Hello
#
# as tokens arrive.
#
# Use
# Tell me a story about AI.
#
# Concepts
# Streaming

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
import os
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(
    model=os.getenv("CHAT_MODEL_NAME"),
    temperature=0
)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI bot. User will give you a question and you have to explain it in 100 words"),
    ("human", "Explain {topic}"),
])

parser = StrOutputParser()

chain = prompt | llm | parser

chunks = chain.stream({
    "topic": "geopolitics"
})

for chunk in chunks:
    print(chunk)
    # print(chunk, end=" ", flush=True)
# Out:
#  Ge opol itics  refers  to  the  study  of  how  geography ,  politics ,  and  economics  interact  to  shape  international  relations  and  global  events .  It  examines  how  countries '  physical  locations ,  resources ,  and  cultural  identities  influence  their  foreign  policies ,  alliances ,  and  conflicts .  Ge opol itics  considers  factors  like  borders ,  trade  routes ,  and  natural  resources  to  understand  the  complex  web  of  global  power  dynamics  and  how  they  impact  international  security ,  trade ,  and  diplomacy .  It  helps  analyze  and  predict  global  trends ,  conflicts ,  and  cooperation ,  making  it  a  crucial  tool  for  policymakers ,  diplomats ,  and  scholars .  It 's  a  multid isc iplinary  field  that  combines  geography ,  politics ,  and  economics .
